# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhilkumar77817/Data-Science/blob/main/DataVisualization_Matplotlib_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[5,6,7,8,9]
plt.plot(x,y) # line plot
plt.show()

# %%
# Movies Data

# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
oscar_years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

plt.plot(oscar_years, oscar_revenue)
plt.title("Oscar Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
# Out:
# Text(0, 0.5, 'Revenue(in $M)')

# %%
# Plot multiple
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend() #an area used to describe the components of a graph, helping viewers understand what each color, line style, or marker represents
plt.show()
# plt.legend(loc="upper right")
# plt.legend(loc="upper left")
# plt.legend(loc="center")

# %% [markdown]
# **Formating**
# Matplotlib offers various ways to format plots, from simple shorthand format strings in the plt.plot()

# %%
plt.clf() # Clear the current figure to ensure a fresh plot
plt.style.use('default') # Reset to default style for consistent plotting

# Plot multiple
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue,"o--r" ,label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue,"*:g", label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend() #an area used to describe the components of a graph, helping viewers understand what each color, line style, or marker represents
plt.show()
# plt.legend(loc="upper right")
# plt.legend(loc="upper left")
# plt.legend(loc="center")

# %%
from matplotlib.lines import lineStyles
# Plot multiple
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue, color="red",marker="o",linestyle="--",linewidth=4,label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue,color="pink",marker="<",linestyle="-",linewidth=6, label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend() #an area used to describe the components of a graph, helping viewers understand what each color, line style, or marker represents
plt.show()
# plt.legend(loc="upper right")
# plt.legend(loc="upper left")
# plt.legend(loc="center")

# %%
plt.clf()
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend() #an area used to describe the components of a graph, helping viewers understand what each color, line style, or marker represents

# print(plt.style.available)
plt.style.use('dark_background')

plt.show()

# %%
plt.clf() # Clear the current figure before plotting
# Plot multiple
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend() #an area used to describe the components of a graph, helping viewers understand what each color, line style, or marker represents

print(plt.style.available)
plt.style.use('ggplot')


plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
with plt.xkcd():
  # Non-Oscar Winner Movies
  non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
  non_oscar_years = [2008, 2009, 2010, 2011, 2012]
  non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

  plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
  plt.plot(non_oscar_years, non_oscar_revenue, label="Non-Oscar Winners")
  plt.title("Years vs Revenue(in $M)")
  plt.xlabel("Years")
  plt.ylabel("Revenue(in $M)")
  plt.legend() #an area used to describe the components of a graph, helping viewers understand what each color, line style, or marker represents

  # print(plt.style.available)
  plt.style.use('dark_background')

  plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# ...

# %%
plt.clf()
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend() #an area used to describe the components of a graph, helping viewers understand what each color, line style, or marker represents

# print(plt.style.available)
plt.style.use('dark_background')

plt.show()

# %%
# Movies Data

# Oscar Winner Movies
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232]  # in $M

plt.plot(oscar_years, oscar_revenue)
plt.title("movies Revenue")
plt.xlabel("movies")
plt.ylabel("Revenue(in $M)")
plt.tight_layout()

# %%
plt.clf() # Clear the current figure
 #barchart -  Rectangular bars of uniform width to represent and compare numerical data across different categories.
 # Oscar Winner Movies
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo",
    "Avtar",
    "Hugo",
    "Lincoln",
    "Slumdog Millionaire"
]
years = [2008, 2009, 2010, 2011, 2012,2013,2014,2015,2016]
revenue = [1005, 170, 427, 133, 232,456,543,234,432]  # in $M

plt.bar(years, revenue,color="pink")
plt.title("movies Revenue")
plt.xlabel("movies")
plt.ylabel("Revenue(in $M)")
plt.tight_layout()
#plt.style.use('classic')
for i in range(len(years)):
  plt.text(years[i],revenue[i]+20, str(revenue[i]),ha = "center", va = "bottom") #ha =horizontal alignment and va= vetical

# if we want to increase the size of graph
# plt.xlim(0,max(revenue)+100)

# %%
# comparing data with bar charts
oscar_movies = ["The Dark Knight","The Hurt Locker","The King's Speech","The Artist","Argo"]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

years = [2008, 2009, 2010, 2011, 2012]

# Plotting Bar Chart
import numpy as np
x = np.arange(len(years))
width = 0.4

plt.bar(x-width/2, oscar_revenue, width, label="Oscar") # shift left
plt.bar(x+width/2, non_oscar_revenue, width, label="Non-Oscar") # shift right

plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")
plt.title("Yearly revenue of Oscar vs Non-Oscar movies")
plt.legend()
plt.tight_layout()

plt.xticks(x, years) # to show x-axis labels
# Out:
# ([<matplotlib.axis.XTick at 0x7b8adce56510>,
# ...
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo",
    "Avtar",
    "Hugo",
    "Lincoln",
    "Slumdog Millionaire"
]
revenue = [1005, 170, 427, 133, 232,456,543,234,432]  # in $M

plt.barh(years, revenue,color="hotpink")
plt.title(" Revenue")
plt.xlabel("movies Name")
# Out:
# Text(0.5, 0, 'movies Name')

# %%
# A scatter plot (or scatter graph) is a data visualization tool that uses dots to represent the values of two different numerical variables, plotting them along a horizontal (x) and vertical (y) axis
# Scatter Plots( check correlation,detect outlier, can create clusters)
people = ["Person A", "Person B", "Person C", "Person D", "Person E",
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

# plot
# plt.scatter(age, blood_pressure, color="red")

plt.title("Age vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid()

# Customizing plots
colors = ["green" if bp<135 else "red" for bp in blood_pressure]
sizes = blood_pressure
plt.scatter(age, blood_pressure, color=colors, s=sizes, marker='^', alpha=0.5)

# plt.scatter(age, blood_pressure, c=blood_pressure, cmap="plasma")
plt.scatter(age, blood_pressure, c=blood_pressure, cmap="OrRd")# makes more sense
# plt.scatter(age, blood_pressure, c=[5]*len(age), cmap="plasma")
plt.colorbar(label="BP")

for i in range(len(age)):
    plt.annotate(people[i], xy=(age[i], blood_pressure[i]))
plt.xlim(min(age), max(age)+10)
# Out:
# (22.0, 75.0)

# %%
# Multiple scatter plots
cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature (°C) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (°C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

# Plots
plt.scatter(winter_temp, winter_humidity, color="blue", label="Winter")
plt.scatter(summer_temp, summer_humidity, color="red", label="Summer")

plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.legend()

# %%
# A pie chart is a circular statistical graphic divided into slices (sectors) to illustrate numerical proportions, where each slice represents a part of a whole

# Pie Charts
expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]

plt.pie(amounts, labels=expenses)

# set style
plt.style.use("ggplot")

# add %-age of each slice
plt.pie(amounts, labels=expenses,  autopct='%1.1f%%')

#set colors
colors = ["purple", "green", "blue", "pink", "yellow"]
plt.pie(amounts, labels=expenses,  autopct='%1.1f%%', colors=colors)

# wedgeprops
plt.pie(amounts, labels=expenses,  autopct='%1.1f%%',
        wedgeprops={"edgecolor":"black", "linewidth": 1, "linestyle":"-", "fill":False}
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x7b8adcbde360>,
# ...
#  [Text(-0.14978333189343454, 1.089754538181375, 'Salaries'),
#   Text(-0.7778173279449521, -0.7778175906654303, 'Rent'),
#   Text(0.14978329725394143, -1.0897545429424635, 'Marketing'),
#   Text(0.8532823048810049, -0.6941968799821561, 'R&D'),
#   Text(1.0840054194235482, -0.18690171390433388, 'Miscellaneous')],
#  [Text(-0.08169999921460065, 0.5944115662807499, '54.3%'),
#   Text(-0.4242639970608829, -0.42426414036296195, '16.3%'),
#   Text(0.08169998032033168, -0.5944115688777073, '13.0%'),
#   Text(0.4654267117532753, -0.37865284362663054, '10.9%'),
#   Text(0.5912756833219354, -0.10194638940236392, '5.4%')])

# %%
# explode
explode = [0, 0, 0, 0.2, 0]
# plt.pie(amounts, labels=expenses, explode=explode)

# shadow
# plt.pie(amounts, labels=expenses, explode=explode, shadow=True)

# angle
plt.pie(amounts, labels=expenses, explode=explode, shadow=True, startangle=90) # top
plt.pie(amounts, labels=expenses, explode=explode, shadow=True, startangle=180) # flips
# Out:
# ([<matplotlib.patches.Wedge at 0x7b8ae0c80e30>,
# ...
#  [Text(0.14978329725394143, -1.0897545429424635, 'Salaries'),
#   Text(0.7778174453921319, 0.7778174732182725, 'Rent'),
#   Text(-0.14978365234103483, 1.0897544941368125, 'Marketing'),
#   Text(-1.0084240270486395, 0.8204151276463673, 'R&D'),
#   Text(-1.0840053912021623, 0.18690187758459628, 'Miscellaneous')])
